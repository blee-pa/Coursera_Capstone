# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
# scrap wiki table from an older version of the page
website_text = requests.get('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=889899728').text
soup = BeautifulSoup(website_text, 'xml')
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# put the data into a df
table_rows = table.find_all('tr')
data = []
for row in table_rows:
    td = []
    for t in row.find_all('td'):
        td.append(t.text.strip())
        data.append(td)
df = pd.DataFrame(data, columns = ['PostalCode', 'Borough', 'Neighborhood'])

# %%
# drop rows where Borough is not assigned.
df = df[df.Borough != 'Not assigned']

# %%
# more than one neighborhood can exist in one postal code area.
df = df.groupby(['PostalCode', 'Borough'])['Neighborhood'].apply(list).apply(
    lambda x:', '.join(x)).to_frame().reset_index()

# %%
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
for index, row in df.iterrows():
    if row['Neighborhood'] == 'Not assigned':
        row ['Neighborhood'] = row['Borough']

# %%
df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# ..         ...               ...
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A      Queen's Park
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0       Rouge, Rouge, Rouge, Malvern, Malvern, Malvern
# 1    Highland Creek, Highland Creek, Highland Creek...
# 2    Guildwood, Guildwood, Guildwood, Morningside, ...
# 3                               Woburn, Woburn, Woburn
# 4                      Cedarbrae, Cedarbrae, Cedarbrae
# 5    Scarborough Village, Scarborough Village, Scar...
# 6    East Birchmount Park, East Birchmount Park, Ea...
# 7    Clairlea, Clairlea, Clairlea, Golden Mile, Gol...
# 8    Cliffcrest, Cliffcrest, Cliffcrest, Cliffside,...
# 9    Birch Cliff, Birch Cliff, Birch Cliff, Cliffsi...
# 10   Dorset Park, Dorset Park, Dorset Park, Scarbor...
# 11   Maryvale, Maryvale, Maryvale, Wexford, Wexford...
# 12                     Agincourt, Agincourt, Agincourt
# 13   Clarks Corners, Clarks Corners, Clarks Corners...
# 14   Agincourt North, Agincourt North, Agincourt No...
# 15   L'Amoreaux West, L'Amoreaux West, L'Amoreaux W...
# 16               Upper Rouge, Upper Rouge, Upper Rouge
# 17   Hillcrest Village, Hillcrest Village, Hillcres...
# 18   Fairview, Fairview, Fairview, Henry Farm, Henr...
# 19   Bayview Village, Bayview Village, Bayview Village
# 20   Silver Hills, Silver Hills, Silver Hills, York...
# 21   Newtonbrook, Newtonbrook, Newtonbrook, Willowd...
# 22   Willowdale South, Willowdale South, Willowdale...
# 23   York Mills West, York Mills West, York Mills West
# 24   Willowdale West, Willowdale West, Willowdale West
# 25                     Parkwoods, Parkwoods, Parkwoods
# 26   Don Mills North, Don Mills North, Don Mills North
# 27   Flemingdon Park, Flemingdon Park, Flemingdon P...
# 28   Bathurst Manor, Bathurst Manor, Bathurst Manor...
# 29   Northwood Park, Northwood Park, Northwood Park...
# ..                                                 ...
# 73   Humewood-Cedarvale, Humewood-Cedarvale, Humewo...
# 74   Caledonia-Fairbanks, Caledonia-Fairbanks, Cale...
# 75                        Christie, Christie, Christie
# 76   Dovercourt Village, Dovercourt Village, Doverc...
# 77   Little Portugal, Little Portugal, Little Portu...
# 78   Brockton, Brockton, Brockton, Exhibition Place...
# 79   Maple Leaf Park, Maple Leaf Park, Maple Leaf P...
# 80   Del Ray, Del Ray, Del Ray, Keelesdale, Keelesd...
# 81   The Junction North, The Junction North, The Ju...
# 82   High Park, High Park, High Park, The Junction ...
# 83   Parkdale, Parkdale, Parkdale, Roncesvalles, Ro...
# 84   Runnymede, Runnymede, Runnymede, Swansea, Swan...
# 85            Not assigned, Not assigned, Not assigned
# 86   Canada Post Gateway Processing Centre, Canada ...
# 87   Business Reply Mail Processing Centre 969 East...
# 88   Humber Bay Shores, Humber Bay Shores, Humber B...
# 89   Alderwood, Alderwood, Alderwood, Long Branch, ...
# 90   The Kingsway, The Kingsway, The Kingsway, Mont...
# 91   Humber Bay, Humber Bay, Humber Bay, King's Mil...
# 92   Kingsway Park South West, Kingsway Park South ...
# 93   Islington Avenue, Islington Avenue, Islington ...
# 94   Cloverdale, Cloverdale, Cloverdale, Islington,...
# 95   Bloordale Gardens, Bloordale Gardens, Bloordal...
# 96         Humber Summit, Humber Summit, Humber Summit
# 97   Emery, Emery, Emery, Humberlea, Humberlea, Hum...
# 98                              Weston, Weston, Weston
# 99                     Westmount, Westmount, Westmount
# 100  Kingsview Village, Kingsview Village, Kingsvie...
# 101  Albion Gardens, Albion Gardens, Albion Gardens...
# 102                    Northwest, Northwest, Northwest
#
# [103 rows x 3 columns]

# %%
df.shape
# Out:
# (103, 3)
